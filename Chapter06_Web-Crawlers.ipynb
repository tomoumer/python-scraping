# %% [markdown]
# # Web Crawlers

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup 
import re
import datetime
import random

# %%
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')

for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1212708853
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1212708853&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-2
# #cite_note-actor-3
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-4
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-5
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-6
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_Limited
# #cite_note-7
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-8
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-9
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-10
# /wiki/Glory_Van_Scott
# #cite_note-walk-11
# #cite_note-bacon-8
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-12
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-8
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-13
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-14
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-15
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-16
# /wiki/Footloose_(1984_film)
# #cite_note-bio-14
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-17
# #cite_note-bacon-8
# #cite_note-18
# #cite_note-19
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-20
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-14
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-21
# /wiki/Tremors_(1990_film)
# #cite_note-22
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-14
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-14
# /wiki/The_New_York_Times
# #cite_note-nyt94-23
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-24
# /wiki/A_Few_Good_Men_(film)
# #cite_note-25
# /wiki/Michael_Greif
# #cite_note-bio-14
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-14
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-14
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-26
# /wiki/Sleepers_(film)
# #cite_note-27
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-14
# /wiki/Losing_Chase
# #cite_note-austin-28
# /wiki/Digging_to_China
# #cite_note-bio-14
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-14
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-29
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-30
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-31
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-32
# /wiki/My_Dog_Skip_(film)
# #cite_note-33
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-34
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-35
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-36
# #cite_note-37
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-38
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-39
# #cite_note-40
# /wiki/The_Following
# #cite_note-41
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-42
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-43
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-44
# /wiki/Instagram
# #cite_note-45
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-46
# /wiki/EE_(telecommunications_company)
# #cite_note-47
# #cite_note-48
# #cite_note-49
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-50
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-51
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-52
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-12
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /w/index.php?title=Travis_Sedgwick&action=edit&redlink=1
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-53
# /wiki/Tracy_Pollan
# #cite_note-54
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-55
# #cite_note-56
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-57
# /wiki/Antireligion
# #cite_note-58
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-59
# #cite_note-60
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-61
# #cite_note-62
# #cite_note-63
# #cite_note-64
# /wiki/Apollo_13_(film)
# #cite_note-65
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-66
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-67
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-68
# /wiki/Denver_Film_Festival
# #cite_note-69
# /wiki/Phoenix_Film_Festival
# #cite_note-70
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-71
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-72
# /wiki/Seattle_International_Film_Festival
# #cite_note-73
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-5
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-6
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-7
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# #cite_ref-bacon_8-0
# #cite_ref-bacon_8-1
# #cite_ref-bacon_8-2
# #cite_ref-bacon_8-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-9
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-10
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_11-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_12-0
# #cite_ref-cosmo91_12-1
# #cite_ref-13
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_14-0
# #cite_ref-bio_14-1
# #cite_ref-bio_14-2
# #cite_ref-bio_14-3
# #cite_ref-bio_14-4
# #cite_ref-bio_14-5
# #cite_ref-bio_14-6
# #cite_ref-bio_14-7
# #cite_ref-bio_14-8
# #cite_ref-bio_14-9
# #cite_ref-bio_14-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_15-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-16
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_17-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-18
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-19
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-20
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-21
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-22
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_23-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-24
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-25
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-26
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-27
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_28-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-29
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-30
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-31
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-32
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# /wiki/Template:Cite_news
# /wiki/Category:CS1_maint:_unfit_URL
# #cite_ref-33
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-34
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-35
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-36
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-37
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_38-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_39-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-40
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-41
# http://www.fox.com/the-following/
# #cite_ref-42
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-43
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-44
# http://baconbros.com/
# #cite_ref-45
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-46
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-47
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-48
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-49
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-50
# http://www.sixdegrees.org/
# #cite_ref-51
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-52
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-53
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-54
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-55
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-56
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-57
# #cite_ref-58
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_59-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-60
# #cite_ref-61
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-62
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-63
# http://www.drawtheline.org/sign-now/
# #cite_ref-64
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-65
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-66
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-67
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-68
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-69
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-70
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-71
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-72
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-73
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# http://id.worldcat.org/fast/242183/
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://d-nb.info/gnd/124109659
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://id.loc.gov/authorities/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# https://lod.nl.go.kr/resource/KAC2020K8226
# http://data.bibliotheken.nl/id/thes/p147880998
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://www.idref.fr/067287832
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1212708853
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_LNB_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_NTA_identifiers
# /wiki/Category:Articles_with_PLWABN_identifiers
# /wiki/Category:Articles_with_MusicBrainz_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_SNAC-ID_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# ## Retrieving Articles Only

# %%
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')

for link in bs.find('div', {'id':'bodyContent'}).find_all(
    # note: they akk start with /wiki/ and don't contain a : in the url
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_Limited
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications_company)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %% [markdown]
# ## Random Walk

# %%
def getLinks(articleUrl):
    html = urlopen(f'http://en.wikipedia.org{articleUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

# %%
# this way results are different each time
random.seed(datetime.datetime.now().strftime('%s'))

links = getLinks('/wiki/Kevin_Bacon')
#while len(links) > 0:
# to make it terminate
for i in range(10):
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Breaking_Bad
# /wiki/Chemical_equation
# /wiki/Phosphoric_acid
# /wiki/Peroxymonosulfuric_acid
# /wiki/Hydrogen_disulfide
# /wiki/International_Chemical_Identifier
# /wiki/Space-filling_model
# /wiki/Chemical_element
# /wiki/Chemical_symbol

# %% [markdown]
# ## Recursively crawling an entire site

# %%
# note that here we're going for all links again, not just articles
# I'm limiting how far it can go (only 1 page deep)
def getAllLinks(pageUrl, pages, maxPageDepth=2, currentPageDepth=0):
    if currentPageDepth == maxPageDepth:
        return

    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getAllLinks(newPage, pages, maxPageDepth, currentPageDepth+1)

# %%
pages = set()

getAllLinks('', pages, 2, 0)
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Talk:Main_Page
# /wiki/Special:WhatLinksHere/Main_Page
# /wiki/Special:RecentChangesLinked/Main_Page
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /wiki/Wikipedia
# /wiki/Free_content
# /wiki/Encyclopedia
# /wiki/Help:Introduction_to_Wikipedia
# /wiki/Special:Statistics
# /wiki/English_language
# /wiki/File:The_Mercury_7_(15258556433).jpg
# /wiki/Mercury_Seven
# /wiki/Astronaut
# /wiki/Project_Mercury
# /wiki/NASA
# /wiki/Scott_Carpenter
# /wiki/Gordon_Cooper
# /wiki/John_Glenn
# /wiki/Gus_Grissom
# /wiki/Wally_Schirra
# /wiki/Alan_Shepard
# /wiki/Deke_Slayton
# /wiki/Project_Gemini
# /wiki/Apollo_program
# /wiki/Space_Shuttle
# /wiki/Apollo_14
# /wiki/Apollo_1
# /wiki/Apollo_7
# /wiki/Atrial_fibrillation
# /wiki/Apollo%E2%80%93Soyuz
# /wiki/Space_Shuttle_Discovery
# /wiki/List_of_spaceflight_records#Age_records
# /wiki/Bob_Mann_(American_football)
# /wiki/The_boy_Jones
# /wiki/Appalachian_Spring
# /wiki/Wikipedia:Today%27s_featured_article/April_2024
# /wiki/Wikipedia:Featured_articles
# /wiki/Wikipedia:About_Today%27s_featured_article
# /wiki/File:Funeral_of_a_Mummy_on_the_Nile_-_Frederick_Arthur_Bridgman.jpg
# /wiki/Funeral_of_a_Mummy_on_the_Nile
# /wiki/South_Ossetia
# /wiki/Religion_in_South_Ossetia
# /wiki/Hildegard_of_Bingen
# /wiki/Physica_(Hildegard)
# /wiki/Cliff_Christl
# /wiki/Green_Bay_Packers
# /wiki/Oral_history
# /wiki/Eurovision_Song_Contest_1992
# /wiki/Johnny_Logan_(singer)
# /wiki/Until_Dawn
# /wiki/List_of_games_by_Supermassive_Games
# /wiki/Sony_Interactive_Entertainment
# /wiki/Seattle_Storm
# /wiki/List_of_Seattle_Storm_seasons
# /wiki/Stan_Brakhage
# /wiki/Sirius_Remembered
# /wiki/Tim_Kinsella
# /wiki/Cap%27n_Jazz
# /wiki/Shmap%27n_Shmazz
# /wiki/Psilocybin_mushroom
# /wiki/Wikipedia:Recent_additions
# /wiki/Help:Your_first_article
# /wiki/Template_talk:Did_you_know
# /wiki/File:Nobel_Prize_24_2013.jpg
# /wiki/Peter_Higgs
# /wiki/Solar_eclipse_of_April_8,_2024
# /wiki/NCAA_Division_I
# /wiki/Basketball
# /wiki/South_Carolina_Gamecocks_women%27s_basketball
# /wiki/2024_NCAA_Division_I_women%27s_basketball_championship_game
# /wiki/2024_NCAA_Division_I_women%27s_basketball_tournament
# /wiki/UConn_Huskies_men%27s_basketball
# /wiki/2024_NCAA_Division_I_men%27s_basketball_championship_game
# /wiki/2024_NCAA_Division_I_men%27s_basketball_tournament
# /wiki/Ecuador%E2%80%93Mexico_relations#2024_diplomatic_crisis
# /wiki/2024_raid_on_the_Mexican_embassy_in_Ecuador
# /wiki/Quito
# /wiki/2024_Hualien_earthquake
# /wiki/Hualien_City
# /wiki/Haitian_crisis_(2018%E2%80%93present)
# /wiki/Israel%E2%80%93Hamas_war
# /wiki/Myanmar_civil_war_(2021%E2%80%93present)
# /wiki/Red_Sea_crisis
# /wiki/Russian_invasion_of_Ukraine
# /wiki/Timeline_of_the_Russian_invasion_of_Ukraine_(1_December_2023_%E2%80%93_present)
# /wiki/Deaths_in_2024
# /wiki/Joe_Kinnear
# /wiki/Thomas_Gumbleton
# /wiki/Notker_Wolf
# /wiki/Chris_Cross
# /wiki/John_Sinclair_(poet)
# /wiki/Anne_Innis_Dagg
# /wiki/Wikipedia:In_the_news/Candidates
# /wiki/April_9
# /wiki/Vimy_Ridge_Day
# /wiki/1917
# /wiki/File:Galer%C3%ADa_Nacional,_Londres,_Inglaterra,_2014-08-07,_DD_035_(cropped).JPG
# /wiki/193
# /wiki/Year_of_the_Five_Emperors
# /wiki/Septimius_Severus
# /wiki/Roman_emperor
# /wiki/Carnuntum
# /wiki/1388
# /wiki/Old_Swiss_Confederacy
# /wiki/Battle_of_N%C3%A4fels
# /wiki/1838
# /wiki/National_Gallery
# /wiki/Trafalgar_Square
# /wiki/London
# /wiki/1939
# /wiki/DAR_Constitution_Hall
# /wiki/Daughters_of_the_American_Revolution
# /wiki/Marian_Anderson
# /wiki/Lincoln_Memorial
# /wiki/Al-Muqtafi
# /wiki/Isambard_Kingdom_Brunel
# /wiki/Mary_Jackson_(engineer)
# /wiki/April_8
# /wiki/April_10
# /wiki/Wikipedia:Selected_anniversaries/April
# /wiki/List_of_days_of_the_year
# /wiki/File:Andasol_5.jpg
# /wiki/Andasol_solar_power_station
# /wiki/Concentrated_solar_power
# /wiki/Parabolic_trough
# /wiki/Guadix
# /wiki/Andalusia
# /wiki/Thermal_energy_storage
# /wiki/Semi-arid_climate
# /wiki/Solar_irradiance
# /wiki/Sierra_Nevada_(Spain)
# /wiki/User:Kallerna
# /wiki/Template:POTD/2024-04-08
# /wiki/Template:POTD/2024-04-07
# /wiki/Template:POTD/2024-04-06
# /wiki/Wikipedia:Picture_of_the_day/Archive
# /wiki/Wikipedia:Featured_pictures
# /wiki/Wikipedia:Village_pump
# /wiki/Wikipedia:News
# /wiki/Wikipedia:Teahouse
# /wiki/Wikipedia:Help_desk
# /wiki/Wikipedia:Reference_desk
# /wiki/Wikipedia:Contents/Portals
# /wiki/Wikimedia_Foundation
# /wiki/Wikipedia:General_disclaimer

# %%
len(pages)
# Out:
# 159

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %% [markdown]
# In this example, crawling Wiki and getting content. Like before, I'm limiting how deep the rabbit hole goes.

# %%
def getLinksContent(pageUrl, pages, maxPageDepth=2, currentPageDepth=0):
    if currentPageDepth == maxPageDepth:
        return
    
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinksContent(newPage, pages, maxPageDepth, currentPageDepth+1)

# %%
pages = set()

getLinksContent('/wiki/General-purpose_programming_language', pages, 2, 0)
# Out:
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Main_Page
# Main Page
# <p>The <b><a href="/wiki/Mercury_Seven" title="Mercury Seven">Mercury Seven</a></b> were a group of American <a href="/wiki/Astronaut" title="Astronaut">astronauts</a> selected to fly spacecraft for <a href="/wiki/Project_Mercury" title="Project Mercury">Project Mercury</a>. Announced by <a href="/wiki/NASA" title="NASA">NASA</a> on April 9, 1959, <a href="/wiki/Scott_Carpenter" title="Scott Carpenter">Scott Carpenter</a>, <a href="/wiki/Gordon_Cooper" title="Gordon Cooper">Gordon Cooper</a>, <a href="/wiki/John_Glenn" title="John Glenn">John Glenn</a>, <a href="/wiki/Gus_Grissom" title="Gus Grissom">Gus Grissom</a>, <a href="/wiki/Wally_Schirra" title="Wally Schirra">Wally Schirra</a>, <a href="/wiki/Alan_Shepard" title="Alan Shepard">Alan Shepard</a>, and <a href="/wiki/Deke_Slayton" title="Deke Slayton">Deke Slayton</a> created a new profession. The group piloted all the spaceflights of the Mercury program that had an astronaut on board from May 1961 to May 1963, and some flew in the <a href="/wiki/Project_Gemini" title="Project Gemini">Gemini</a>, <a href="/wiki/Apollo_program" title="Apollo program">Apollo</a>, and <a href="/wiki/Space_Shuttle" title="Space Shuttle">Space Shuttle</a> programs. Shepard became the first American to enter space in 1961, and <a href="/wiki/Apollo_14" title="Apollo 14">walked on the Moon in 1971</a>. Grissom, after flying Mercury and Gemini missions, died in 1967 in the <a href="/wiki/Apollo_1" title="Apollo 1">Apollo 1</a> fire; the others survived past retirement from service. Schirra commanded <a href="/wiki/Apollo_7" title="Apollo 7">Apollo 7</a>, the first crewed Apollo flight. Slayton, grounded with <a href="/wiki/Atrial_fibrillation" title="Atrial fibrillation">atrial fibrillation</a>, ultimately flew on the <a href="/wiki/Apollo%E2%80%93Soyuz" title="Apollo–Soyuz">Apollo–Soyuz Test Project</a> in 1975. Glenn became the first American in orbit in 1962, and flew on Space Shuttle <i><a href="/wiki/Space_Shuttle_Discovery" title="Space Shuttle Discovery">Discovery</a></i> in 1998 to become, at age 77, the <a href="/wiki/List_of_spaceflight_records#Age_records" title="List of spaceflight records">oldest person to fly in space</a> at the time. (<b><a href="/wiki/Mercury_Seven" title="Mercury Seven">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# --------------------
# /wiki/Portal:Current_events
# --------------------
# /wiki/Special:Random
# --------------------
# /wiki/Wikipedia:About
# --------------------
# /wiki/Help:Contents
# --------------------
# /wiki/Help:Introduction
# --------------------
# /wiki/Wikipedia:Community_portal
# --------------------
# /wiki/Special:RecentChanges
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# --------------------
# /wiki/Special:Search
# --------------------
# /wiki/Special:MyContributions
# --------------------
# /wiki/Special:MyTalk
# --------------------
# /wiki/Talk:Main_Page
# --------------------
# /wiki/Special:WhatLinksHere/Main_Page
# --------------------
# /wiki/Special:RecentChangesLinked/Main_Page
# --------------------
# /wiki/Wikipedia:File_Upload_Wizard
# --------------------
# /wiki/Special:SpecialPages
# --------------------
# /wiki/Wikipedia
# --------------------
# /wiki/Free_content
# --------------------
# /wiki/Encyclopedia
# --------------------
# /wiki/Help:Introduction_to_Wikipedia
# --------------------
# /wiki/Special:Statistics
# --------------------
# /wiki/English_language
# --------------------
# /wiki/File:The_Mercury_7_(15258556433).jpg
# --------------------
# /wiki/Mercury_Seven
# --------------------
# /wiki/Astronaut
# --------------------
# /wiki/Project_Mercury
# --------------------
# /wiki/NASA
# --------------------
# /wiki/Scott_Carpenter
# --------------------
# /wiki/Gordon_Cooper
# --------------------
# /wiki/John_Glenn
# --------------------
# /wiki/Gus_Grissom
# --------------------
# /wiki/Wally_Schirra
# --------------------
# /wiki/Alan_Shepard
# --------------------
# /wiki/Deke_Slayton
# --------------------
# /wiki/Project_Gemini
# --------------------
# /wiki/Apollo_program
# --------------------
# /wiki/Space_Shuttle
# --------------------
# /wiki/Apollo_14
# --------------------
# /wiki/Apollo_1
# --------------------
# /wiki/Apollo_7
# --------------------
# /wiki/Atrial_fibrillation
# --------------------
# /wiki/Apollo%E2%80%93Soyuz
# --------------------
# /wiki/Space_Shuttle_Discovery
# --------------------
# /wiki/List_of_spaceflight_records#Age_records
# --------------------
# /wiki/Bob_Mann_(American_football)
# --------------------
# /wiki/The_boy_Jones
# --------------------
# /wiki/Appalachian_Spring
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/April_2024
# --------------------
# /wiki/Wikipedia:Featured_articles
# --------------------
# /wiki/Wikipedia:About_Today%27s_featured_article
# --------------------
# /wiki/File:Funeral_of_a_Mummy_on_the_Nile_-_Frederick_Arthur_Bridgman.jpg
# --------------------
# /wiki/Funeral_of_a_Mummy_on_the_Nile
# --------------------
# /wiki/South_Ossetia
# --------------------
# /wiki/Religion_in_South_Ossetia
# --------------------
# /wiki/Hildegard_of_Bingen
# --------------------
# /wiki/Physica_(Hildegard)
# --------------------
# /wiki/Cliff_Christl
# --------------------
# /wiki/Green_Bay_Packers
# --------------------
# /wiki/Oral_history
# --------------------
# /wiki/Eurovision_Song_Contest_1992
# --------------------
# /wiki/Johnny_Logan_(singer)
# --------------------
# /wiki/Until_Dawn
# --------------------
# /wiki/List_of_games_by_Supermassive_Games
# --------------------
# /wiki/Sony_Interactive_Entertainment
# --------------------
# /wiki/Seattle_Storm
# --------------------
# /wiki/List_of_Seattle_Storm_seasons
# --------------------
# /wiki/Stan_Brakhage
# --------------------
# /wiki/Sirius_Remembered
# --------------------
# /wiki/Tim_Kinsella
# --------------------
# /wiki/Cap%27n_Jazz
# --------------------
# /wiki/Shmap%27n_Shmazz
# --------------------
# /wiki/Psilocybin_mushroom
# --------------------
# /wiki/Wikipedia:Recent_additions
# --------------------
# /wiki/Help:Your_first_article
# --------------------
# /wiki/Template_talk:Did_you_know
# --------------------
# /wiki/File:Nobel_Prize_24_2013.jpg
# --------------------
# /wiki/Peter_Higgs
# --------------------
# /wiki/Solar_eclipse_of_April_8,_2024
# --------------------
# /wiki/NCAA_Division_I
# --------------------
# /wiki/Basketball
# --------------------
# /wiki/South_Carolina_Gamecocks_women%27s_basketball
# --------------------
# /wiki/2024_NCAA_Division_I_women%27s_basketball_championship_game
# --------------------
# /wiki/2024_NCAA_Division_I_women%27s_basketball_tournament
# --------------------
# /wiki/UConn_Huskies_men%27s_basketball
# --------------------
# /wiki/2024_NCAA_Division_I_men%27s_basketball_championship_game
# --------------------
# /wiki/2024_NCAA_Division_I_men%27s_basketball_tournament
# --------------------
# /wiki/Ecuador%E2%80%93Mexico_relations#2024_diplomatic_crisis
# --------------------
# /wiki/2024_raid_on_the_Mexican_embassy_in_Ecuador
# --------------------
# /wiki/Quito
# --------------------
# /wiki/2024_Hualien_earthquake
# --------------------
# /wiki/Hualien_City
# --------------------
# /wiki/Haitian_crisis_(2018%E2%80%93present)
# --------------------
# /wiki/Israel%E2%80%93Hamas_war
# --------------------
# /wiki/Myanmar_civil_war_(2021%E2%80%93present)
# --------------------
# /wiki/Red_Sea_crisis
# --------------------
# /wiki/Russian_invasion_of_Ukraine
# --------------------
# /wiki/Timeline_of_the_Russian_invasion_of_Ukraine_(1_December_2023_%E2%80%93_present)
# --------------------
# /wiki/Deaths_in_2024
# --------------------
# /wiki/Joe_Kinnear
# --------------------
# /wiki/Thomas_Gumbleton
# --------------------
# /wiki/Notker_Wolf
# --------------------
# /wiki/Chris_Cross
# --------------------
# /wiki/John_Sinclair_(poet)
# --------------------
# /wiki/Anne_Innis_Dagg
# --------------------
# /wiki/Wikipedia:In_the_news/Candidates
# --------------------
# /wiki/April_9
# --------------------
# /wiki/Vimy_Ridge_Day
# --------------------
# /wiki/1917
# --------------------
# /wiki/File:Galer%C3%ADa_Nacional,_Londres,_Inglaterra,_2014-08-07,_DD_035_(cropped).JPG
# --------------------
# /wiki/193
# --------------------
# /wiki/Year_of_the_Five_Emperors
# --------------------
# /wiki/Septimius_Severus
# --------------------
# /wiki/Roman_emperor
# --------------------
# /wiki/Carnuntum
# --------------------
# /wiki/1388
# --------------------
# /wiki/Old_Swiss_Confederacy
# --------------------
# /wiki/Battle_of_N%C3%A4fels
# --------------------
# /wiki/1838
# --------------------
# /wiki/National_Gallery
# --------------------
# /wiki/Trafalgar_Square
# --------------------
# /wiki/London
# --------------------
# /wiki/1939
# --------------------
# /wiki/DAR_Constitution_Hall
# --------------------
# /wiki/Daughters_of_the_American_Revolution
# --------------------
# /wiki/Marian_Anderson
# --------------------
# /wiki/Lincoln_Memorial
# --------------------
# /wiki/Al-Muqtafi
# --------------------
# /wiki/Isambard_Kingdom_Brunel
# --------------------
# /wiki/Mary_Jackson_(engineer)
# --------------------
# /wiki/April_8
# --------------------
# /wiki/April_10
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/April
# --------------------
# /wiki/List_of_days_of_the_year
# --------------------
# /wiki/File:Andasol_5.jpg
# --------------------
# /wiki/Andasol_solar_power_station
# --------------------
# /wiki/Concentrated_solar_power
# --------------------
# /wiki/Parabolic_trough
# --------------------
# /wiki/Guadix
# --------------------
# /wiki/Andalusia
# --------------------
# /wiki/Thermal_energy_storage
# --------------------
# /wiki/Semi-arid_climate
# --------------------
# /wiki/Solar_irradiance
# --------------------
# /wiki/Sierra_Nevada_(Spain)
# --------------------
# /wiki/User:Kallerna
# --------------------
# /wiki/Template:POTD/2024-04-08
# --------------------
# /wiki/Template:POTD/2024-04-07
# --------------------
# /wiki/Template:POTD/2024-04-06
# --------------------
# /wiki/Wikipedia:Picture_of_the_day/Archive
# --------------------
# /wiki/Wikipedia:Featured_pictures
# --------------------
# /wiki/Wikipedia:Village_pump
# --------------------
# /wiki/Wikipedia:News
# --------------------
# /wiki/Wikipedia:Teahouse
# --------------------
# /wiki/Wikipedia:Help_desk
# --------------------
# /wiki/Wikipedia:Reference_desk
# --------------------
# /wiki/Wikipedia:Contents/Portals
# --------------------
# /wiki/Wikimedia_Foundation
# --------------------
# /wiki/Wikipedia:General_disclaimer
# --------------------
# /wiki/General-purpose_programming_language
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Talk:General-purpose_programming_language
# --------------------
# /wiki/Special:WhatLinksHere/General-purpose_programming_language
# --------------------
# /wiki/Special:RecentChangesLinked/General-purpose_programming_language
# --------------------
# /wiki/Computer_software
# --------------------
# /wiki/Programming_language
# --------------------
# /wiki/Software
# --------------------
# /wiki/Domain_(software_engineering)
# --------------------
# /wiki/Domain-specific_language
# --------------------
# /wiki/Python_(programming_language)
# --------------------
# /wiki/SQL
# --------------------
# /wiki/Query_language
# --------------------
# /wiki/Fortran
# --------------------
# /wiki/ALGOL
# --------------------
# /wiki/COBOL
# --------------------
# /wiki/Record_(computer_science)
# --------------------
# /wiki/IPL-V
# --------------------
# /wiki/LISP
# --------------------
# /wiki/List_(abstract_data_type)
# --------------------
# /wiki/COMIT
# --------------------
# /wiki/APT_(programming_language)
# --------------------
# /wiki/Numerical_control
# --------------------
# /wiki/Systems_programming
# --------------------
# /wiki/Pointer_(computer_programming)
# --------------------
# /wiki/Assembly_language
# --------------------
# /wiki/JOVIAL
# --------------------
# /wiki/IBM
# --------------------
# /wiki/IBM_System/360
# --------------------
# /wiki/PL/I
# --------------------
# /wiki/Multics
# --------------------
# /wiki/Database#Database_management_system
# --------------------
# /wiki/GPSS
# --------------------
# /wiki/Simula
# --------------------
# /wiki/MAD_(programming_language)
# --------------------
# /wiki/BASIC
# --------------------
# /wiki/Logo_(programming_language)
# --------------------
# /wiki/Pascal_(programming_language)
# --------------------
# /wiki/C_(programming_language)
# --------------------
# /wiki/JOSS
# --------------------
# /wiki/APL/360
# --------------------
# /wiki/Lisp_(programming_language)
# --------------------
# /wiki/Wikipedia:Accuracy_dispute#Disputed_statement
# --------------------
# /wiki/Talk:General-purpose_programming_language#Dubious
# --------------------
# /wiki/Turing_completeness
# --------------------
# /wiki/Java_(programming_language)
# --------------------
# /wiki/C%EF%BC%83_(programming_language)
# --------------------
# /wiki/Extensible_Application_Markup_Language
# --------------------
# /wiki/B_(programming_language)
# --------------------
# /wiki/Operating_system
# --------------------
# /wiki/Device_driver
# --------------------
# /wiki/Application_software
# --------------------
# /wiki/Embedded_system
# --------------------
# /wiki/Unix
# --------------------
# /wiki/Doom_(franchise)
# --------------------
# /wiki/C%2B%2B
# --------------------
# /wiki/Object-oriented_programming
# --------------------
# /wiki/Microsoft
# --------------------
# /wiki/Apple_Inc.
# --------------------
# /wiki/Bloomberg_L.P.
# --------------------
# /wiki/Morgan_Stanley
# --------------------
# /wiki/Django_(web_framework)
# --------------------
# /wiki/Flask_(web_framework)
# --------------------
# /wiki/SciPy
# --------------------
# /wiki/Pandas_(software)
# --------------------
# /wiki/Scikit-learn
# --------------------
# /wiki/TensorFlow
# --------------------
# /wiki/List_of_programming_languages
# --------------------
# /wiki/C_Sharp_(programming_language)
# --------------------
# /wiki/Clojure
# --------------------
# /wiki/Crystal_(programming_language)
# --------------------
# /wiki/D_(programming_language)
# --------------------
# /wiki/Dart_(programming_language)
# --------------------
# /wiki/Delphi_(software)
# --------------------
# /wiki/Elixir_(programming_language)
# --------------------
# /wiki/Erlang_(programming_language)
# --------------------
# /wiki/F_Sharp_(programming_language)
# --------------------
# /wiki/Go_(programming_language)
# --------------------
# /wiki/Harbour_compiler
# --------------------
# /wiki/Haskell_(programming_language)
# --------------------
# /wiki/JavaScript_(programming_language)
# --------------------
# /wiki/Julia_(programming_language)
# --------------------
# /wiki/Kotlin_(programming_language)
# --------------------
# /wiki/Lua_(programming_language)
# --------------------
# /wiki/Modula-2
# --------------------
# /wiki/Oberon_(programming_language)
# --------------------
# /wiki/Objective-C
# --------------------
# /wiki/OCaml
# --------------------
# /wiki/Perl
# --------------------
# /wiki/PHP
# --------------------
# /wiki/Pike_(programming_language)
# --------------------
# /wiki/Racket_(programming_language)
# --------------------
# /wiki/Ruby_(programming_language)
# --------------------
# /wiki/Rust_(programming_language)
# --------------------
# /wiki/Scala_(programming_language)
# --------------------
# /wiki/Swift_(programming_language)
# --------------------
# /wiki/Tcl
# --------------------
# /wiki/V_(programming_language)
# --------------------
# /wiki/Visual_Basic
# --------------------
# /wiki/Visual_Basic_.NET
# --------------------
# /wiki/Zig_(programming_language)
# --------------------
# /wiki/General-purpose_markup_language
# --------------------
# /wiki/General-purpose_modeling_language
# --------------------
# /wiki/Doi_(identifier)
# --------------------
# /wiki/CiteSeerX_(identifier)
# --------------------
# /wiki/Template:Cite_journal
# --------------------
# /wiki/Help:CS1_errors#missing_periodical
# --------------------
# /wiki/ISSN_(identifier)
# --------------------
# /wiki/S2CID_(identifier)
# --------------------
# /wiki/Bell_Telephone_Laboratories
# --------------------
# /wiki/ISBN_(identifier)
# --------------------
# /wiki/Special:BookSources/978-0-13-110370-2
# --------------------
# /wiki/OCLC_(identifier)
# --------------------
# /wiki/Template:Cite_book
# --------------------
# /wiki/Category:CS1_maint:_multiple_names:_authors_list
# --------------------
# /wiki/ArXiv_(identifier)
# --------------------
# /wiki/Bibcode_(identifier)
# --------------------
# /wiki/Help:Category
# --------------------
# /wiki/Category:Programming_languages
# --------------------
# /wiki/Category:CS1_errors:_missing_periodical
# --------------------
# /wiki/Category:Articles_with_short_description
# --------------------
# /wiki/Category:Short_description_is_different_from_Wikidata
# --------------------
# /wiki/Category:All_accuracy_disputes
# --------------------
# /wiki/Category:Articles_with_disputed_statements_from_December_2022

# %% [markdown]
# ## Crawling across the Internet

# %% [markdown]
# like before, I added a max links to follow...
#
# note: if using requests library, in order to let internal servers redirect, it needs to be specified (urlparse instead does it automatically)

# %%
urlparse('https://www.tomoumer.com')
# Out:
# ParseResult(scheme='https', netloc='www.tomoumer.com', path='', params='', query='', fragment='')

# %%
#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks):
        print('No external links, looking around the site for one')
        internalLinks = getInternalLinks(bs, startingPage)
        return getRandomExternalLink(random.choice(internalLinks))
    else:
        return random.choice(externalLinks)
    
def followExternalOnly(startingSite, maxFollow=5, currentFollow=0):
    if maxFollow == currentFollow:
        return
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink, maxFollow, currentFollow + 1)

# %%
followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://www.oreilly.co.jp/index.shtml
# Random external link is: https://makezine.jp/
# Random external link is: https://eepurl.com/bJoWZf
# Random external link is: https://login.mailchimp.com/signup/email-referral/?aid=f1be389980677f59500fb9203
# Random external link is: https://www.creditkarma.com/

# %% [markdown]
# ## Collect all External Links from a Site

# %%
def getAllExternalLinks(url, allExtLinks, allIntLinks, maxPageDepth=3, currentPageDepth=0):
    if currentPageDepth == maxPageDepth:
        return
    bs = BeautifulSoup(urlopen(url), 'html.parser')
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)

    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link, allExtLinks, allIntLinks, maxPageDepth, currentPageDepth + 1)

# %%
# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []

allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/', allExtLinks, allIntLinks, 3, 0)
# Out:
# https://oreilly.hk/
# https://learning.oreilly.com/search/?query=author%3A%22Ken%20Kousen%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://oreilly.id/
# https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# https://learning.oreilly.com/search/?query=author%3A%22Arianne%20Dee%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=suggestion&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://learning.oreilly.com/start-trial/
# https://learning.oreilly.com/search/?query=author%3A%22Bruno%20Gon%C3%A7alves%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.linkedin.com/company/oreilly-media
# https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.youtube.com/user/OreillyMedia
# https://learning.oreilly.com/search/?query=author%3A%22Kelsey%20Hightower%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.oreilly.co.jp/index.shtml
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://oreillylearning.in/
# https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/interactive/
# https://oreillymedia.zoom.us/webinar/register/WN_GhuUgqRkTdW6j6SidumwQQ
# https://oreillymedia.zoom.us/webinar/register/WN_9Wf24ZPJQ0GrF9ocSIWaTQ#/registration
# https://oreillymedia.zoom.us/webinar/register/7117065549832/WN_eSyWbFQHQw-hqQv-6hU6KA
# https://oreillymedia.zoom.us/webinar/register/7817065567200/WN_7NWZ5nNtSkqx0q1UD98AfA
# https://oreillymedia.zoom.us/webinar/register/6217065570792/WN_7Raf_QDSQzi1b7CjFFlRFg
# https://oreillymedia.zoom.us/webinar/register/WN__2KY9y6NR3yKKXe2cU1gVQ
# https://oreillymedia.zoom.us/webinar/register/5417065543859/WN_mGoi2Z8USIeJRmQE7xVSKQ
# https://learning.oreilly.com/team-setup/
# https://oreillymedia.zoom.us/webinar/register/1417065581619/WN_8cS69XraTEqRundrfQrQog#/registration
# https://oreillymedia.zoom.us/webinar/register/7117065564022/WN_JdWjaC8dR1-046lZDsDx1w
# https://oreillymedia.zoom.us/webinar/register/8617065580679/WN_63BvaJ-FT9irZ5Ex1xIvGw#/registration
# https://oreillymedia.zoom.us/webinar/register/2617113058891/WN_eiNPYnWjQl-QUU1WA44RYw#/registration
# https://oreillymedia.zoom.us/webinar/register/5817113056533/WN_UB-atE8kR6G1YgD5MkLahA#/registration
# https://oreillymedia.zoom.us/webinar/register/WN_3UIdHZEUQui8lXZT4GJAyQ
# https://oreillymedia.zoom.us/webinar/register/4717065539508/WN__Macf5moSb2dFAjohPGoMA
# https://oreillymedia.zoom.us/webinar/register/2217065573052/WN_c6Qyox_NQQ-pVplxkY2ssQ#/registration
# https://webportalapp.com/sp/oreilly_deij_application
