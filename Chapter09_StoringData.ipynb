# %% [markdown]
# # Storing Data

# %%
import os
from urllib.request import urlretrieve, urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import sqlite3
import csv

import random
import re
from random import shuffle

# %%
html = urlopen('http://www.pythonscraping.com')
bs = BeautifulSoup(html, 'html.parser')
imageLocation = bs.find('img', {'alt': 'python-logo'})['src']
urlretrieve (imageLocation, 'logo.jpg')
# Out:
# ('logo.jpg', <http.client.HTTPMessage at 0x1079dc5f0>)

# %%
def getAbsoluteURL(source, baseUrl):
    if urlparse(baseUrl).netloc == '':
        return baseUrl + source
    return source

def getDownloadPath(fileUrl, downloadDir):
    parsed = urlparse(fileUrl)
    netloc = parsed.netloc.strip('/')
    path = parsed.path.strip('/')
    localfile = f'{downloadDir}/{netloc}/{path}'
    
    # Remove the filename from the path in order to 
    # make the directory structure leading up to it
    localpath = '/'.join(localfile.split('/')[:-1])
    if not os.path.exists(localpath):
        os.makedirs(localpath)
    return localfile

# %%
downloadDir = 'downloaded'
baseUrl = 'https://pythonscraping.com/'
baseNetloc = urlparse(baseUrl).netloc

html = urlopen(baseUrl)
bs = BeautifulSoup(html, 'html.parser')
downloadList = bs.findAll(src=True)

for download in downloadList:
    fileUrl = getAbsoluteURL(download['src'], baseUrl)
    if fileUrl is not None:
        try:
            urlretrieve(fileUrl, getDownloadPath(fileUrl, downloadDir))
            print(fileUrl)
        except Exception as e:
            print(f'Could not retrieve {fileUrl} Error: {e}')
# Out:
# https://pythonscraping.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.1
# https://pythonscraping.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.4.1
# https://pythonscraping.com/wp-content/plugins/pagelayer/js/combined.js?ver=1.7.5
# https://pythonscraping.com/wp-content/plugins/email-capture-lead-generation//js/eclg-public.js?ver=1.0.1
# https://www.googletagmanager.com/gtag/js?id=GT-TNFZZK6
# https://pythonscraping.com/wp-content/uploads/2023/04/python-logo-e1681354047443.png
# https://pythonscraping.com/wp-content/uploads/2021/08/home1.jpg
# https://pythonscraping.com/wp-content/uploads/2021/08/logo01-e1681353135199.png
# https://pythonscraping.com/wp-content/plugins/email-capture-lead-generation//images/ajax_loader.gif
# https://pythonscraping.com/wp-content/plugins/contact-form-7/includes/swv/js/index.js?ver=5.7.7
# https://pythonscraping.com/wp-content/plugins/contact-form-7/includes/js/index.js?ver=5.7.7
# https://pythonscraping.com/wp-content/themes/popularfx/js/navigation.js?ver=1.2.0

# %%
csvFile = open('test.csv', 'w+')
try:
    writer = csv.writer(csvFile)
    writer.writerow(('number', 'number plus 2', 'number times 2'))
    for i in range(10):
        writer.writerow( (i, i+2, i*2))
finally:
    csvFile.close()

# %%
html = urlopen('http://en.wikipedia.org/wiki/Comparison_of_text_editors')
bs = BeautifulSoup(html, 'html.parser')
# The main comparison table is currently the first table on the page
table = bs.find('table',{'class':'wikitable'})
rows = table.findAll('tr')
csvFile = open('editors.csv', 'wt+')
writer = csv.writer(csvFile)
try:
    for row in rows:
        csvRow = []
        for cell in row.findAll(['td', 'th']):
            csvRow.append(cell.get_text().strip())
        writer.writerow(csvRow)
finally:
    csvFile.close()

# %%
# taken from GEEKS for GEEKS
# Connecting to sqlite
# connection object
db = sqlite3.connect('storing_data.sqlite')
 
# cursor object
cursor = db.cursor()
 
# Drop the table if already exists.
cursor.execute("DROP TABLE IF EXISTS pages")
 
# Creating table
# note primary key automatically auto increments
table = """ CREATE TABLE pages (
            id INTEGER PRIMARY KEY,
            title NVARCHAR(200),
            content NVARCHAR(10000),
            created TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        ); """
 
cursor.execute(table)
 
print("Table is Ready")
 
# Close the connection
db.close()
# Out:
# Table is Ready

# %%
def store(title, content, cursor):
    # NOTE: the replace " is needed because otherwise it will breake it (since it's in double quotes inside the query)
    content = content.replace('"', '""')
    cursor.execute(f'INSERT INTO pages (title, content) VALUES ("{title}", "{content}")')
    cursor.connection.commit()

def getLinks(articleUrl, cursor):
    html = urlopen('http://en.wikipedia.org'+articleUrl)
    bs = BeautifulSoup(html, 'html.parser')
    title = bs.find('h1').get_text()
    content = bs.find('div', {'id':'mw-content-text'}).find('p').get_text()
    store(title, content, cursor)
    return bs.find('div', {'id':'bodyContent'}).findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))

# %%
db = sqlite3.connect('storing_data.sqlite')
cursor = db.cursor()

links = getLinks('/wiki/Kevin_Bacon', cursor)
try:
    while len(links) > 0:
         newArticle = links[random.randint(0, len(links)-1)].attrs['href']
         print(newArticle)
         links = getLinks(newArticle, cursor)
finally:
    db.close()
# Out:
# /wiki/Ghent_International_Film_Festival
# /wiki/Gaston_Kabor%C3%A9
# /wiki/IMDb_(identifier)
# /wiki/Vince_Chhabria
# /wiki/James_A._Soto
# /wiki/Cathy_Ann_Bencivengo
# /wiki/James_A._Soto
# /wiki/Miranda_Du
# /wiki/University_of_California,_Davis
# /wiki/US_Club_Soccer
# /wiki/MLS_Next
# /wiki/Sacramento_Republic_FC
# /wiki/ESPN
# /wiki/Midland_Daily_News
# /wiki/WLWT
# /wiki/Comet_(TV_network)
# /wiki/The_Ray_Bradbury_Theater
# /wiki/The_Casual_Vacancy_(miniseries)
# /wiki/Mind_Over_Murder_(TV_series)
# /wiki/The_Baby_(TV_series)
# /wiki/The_Chris_Rock_Show
# /wiki/Wynton_Marsalis
# /wiki/Ben_Stein
# /wiki/Pseudoscience
# /wiki/Scientometrics
# /wiki/ArXiv_(identifier)
# /wiki/Doi_(identifier)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[142], line 9
#       7          newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#       8          print(newArticle)
# ----> 9          links = getLinks(newArticle, cursor)
#      10 finally:
#      11     db.close()
#
# Cell In[141], line 9, in getLinks(articleUrl, cursor)
#       7 def getLinks(articleUrl, cursor):
#       8     html = urlopen('http://en.wikipedia.org'+articleUrl)
# ----> 9     bs = BeautifulSoup(html, 'html.parser')
#      10     title = bs.find('h1').get_text()
#      11     content = bs.find('div', {'id':'mw-content-text'}).find('p').get_text()
#
# File ~/anaconda3/envs/webscraping/lib/python3.12/site-packages/bs4/__init__.py:314, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 self.parse_only = parse_only
#     313 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 314     markup = markup.read()
#     315 elif len(markup) <= 256 and (
#     316         (isinstance(markup, bytes) and not b'<' in markup)
#     317         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     321     # Beautiful Soup will still parse the input as markup,
#     322     # since that is sometimes the intended behavior.
#     323     if not self._markup_is_url(markup):
#
# File ~/anaconda3/envs/webscraping/lib/python3.12/http/client.py:495, in HTTPResponse.read(self, amt)
#     493 else:
#     494     try:
# --> 495         s = self._safe_read(self.length)
#     496     except IncompleteRead:
#     497         self._close_conn()
#
# File ~/anaconda3/envs/webscraping/lib/python3.12/http/client.py:640, in HTTPResponse._safe_read(self, amt)
#     633 def _safe_read(self, amt):
#     634     """Read the number of bytes requested.
#     635
#     636     This function should be used when <amt> bytes "should" be present for
#     637     reading. If the bytes are truly not available (due to EOF), then the
#     638     IncompleteRead exception can be used to detect the problem.
#     639     """
# --> 640     data = self.fp.read(amt)
#     641     if len(data) < amt:
#     642         raise IncompleteRead(data, amt-len(data))
#
# File ~/anaconda3/envs/webscraping/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/anaconda3/envs/webscraping/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/webscraping/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with sqlite3.connect('storing_data.sqlite') as db:
    print(db.execute('SELECT * FROM pages').fetchall())
# Out:
# [(1, 'Kevin Bacon', '\n', '2024-04-17 01:12:17'), (2, 'Film Fest Gent', '\n', '2024-04-17 01:12:18'), (3, 'Gaston Kaboré', "Gaston Kaboré (born 1951) is a Burkinabé film director and an important figure in Burkina Faso's film industry.[1] He has won awards for his films Wend Kuuni and Buud Yam. He is the founder of Imagine Institute, a school he opened in Ouagadougou, Burkina Faso in 2003, that provides workshops and residencies for film and television professionals.\n", '2024-04-17 01:12:18'), (4, 'IMDb', '\n', '2024-04-17 01:12:19'), (5, 'Vince Chhabria', "Vince Girdhari Chhabria (born November 27, 1969) is a United States district judge of the United States District Court for the Northern District of California and formerly a deputy city attorney at the San Francisco City Attorney's Office.\n", '2024-04-17 01:12:19'), (6, 'James A. Soto', 'James Alan Soto (born July 1, 1950) is  a United States district judge of the United States District Court for the District of Arizona and former Arizona state court judge.\n', '2024-04-17 01:12:19'), (7, 'Cathy Ann Bencivengo', 'Cathy Ann Palumbo Bencivengo (born August 24, 1958) is a United States district judge of the United States District Court for the Southern District of California.\n', '2024-04-17 01:12:20'), (8, 'James A. Soto', 'James Alan Soto (born July 1, 1950) is  a United States district judge of the United States District Court for the District of Arizona and former Arizona state court judge.\n', '2024-04-17 01:12:20'), (9, 'Miranda Du', '\n', '2024-04-17 01:12:21'), (10, 'University of California, Davis', '\n', '2024-04-17 01:12:22'), (11, 'US Club Soccer', '\n', '2024-04-17 01:12:22'), (12, 'MLS Next', '\n', '2024-04-17 01:12:22'), (13, 'Sacramento Republic FC', '\n', '2024-04-17 01:12:23'), (14, 'ESPN', '\n', '2024-04-17 01:12:24'), (15, 'Midland Daily News', 'The Midland Daily News is a daily newspaper which serves Midland County, Michigan.  The offices for the paper are located at 219 East Main Street in downtown Midland; the paper is widely circulated around Midland County.\n', '2024-04-17 01:12:24'), (16, 'WLWT', '\n', '2024-04-17 01:12:25'), (17, 'Comet (TV network)', "Comet is an American digital broadcast television network owned by the Sinclair Television Group subsidiary of the Sinclair Broadcast Group.[2] The network focuses on science fiction with some supernatural, horror, adventure and fantasy series and films, sourced mainly from the Metro-Goldwyn-Mayer film and television library.[5][4] Sinclair also owns Charge! (action), The Nest (reality) and TBD (youth) broadcast networks. Comet is also available via Apple TV, FuboTV, YouTubeTV, Roku, Sling TV, Dish Network and Sinclair's Stirr.\n", '2024-04-17 01:12:25'), (18, 'The Ray Bradbury Theater', 'The Ray Bradbury Theatre is an anthology series that ran for three seasons on First Choice Superchannel in Canada and HBO in the United States from 1985 to 1986, and then on USA Network, running for four additional seasons from 1988 to 1992;[1] episodes aired on the Global Television Network in Canada from 1991 to 1994. It was shown in reruns on the Sci Fi Channel[2] and later on the Retro Television Network. It currently airs on Comet and can be streamed on IMDb TV, Peacock, Pluto TV and The Roku Channel.\n', '2024-04-17 01:12:25'), (19, 'The Casual Vacancy (miniseries)', '\n', '2024-04-17 01:12:26'), (20, 'Mind Over Murder (TV series)', 'Mind Over Murder is a 2022 American documentary television miniseries revolving around the Beatrice Six, directed by Nanfu Wang. It consists of 6 episodes and premiered on June 20, 2022, on HBO.\n', '2024-04-17 01:12:27'), (21, 'The Baby (TV series)', '\n', '2024-04-17 01:12:27'), (22, 'The Chris Rock Show', 'The Chris Rock Show was a weekly, Friday night, late-night talk show featured on HBO. It was created by comedian and namesake Chris Rock and featured various guests. The show won an Emmy for Outstanding Writing for a Variety or Music Program in 1999. It ran for five seasons f ...

# %%
# CODE FROM AUTHOR, using pymysql
# import pymysql

# conn = pymysql.connect(host='127.0.0.1', unix_socket='/tmp/mysql.sock',
#                        user='root', passwd='password', db='mysql', charset='utf8')
# cur = conn.cursor()
# cur.execute('USE scraping')

# def store(title, content):
#     cur.execute('INSERT INTO pages (title, content) VALUES ("%s", "%s")', (title, content))
#     cur.connection.commit()

# def getLinks(articleUrl):
#     html = urlopen('http://en.wikipedia.org'+articleUrl)
#     bs = BeautifulSoup(html, 'html.parser')
#     title = bs.find('h1').get_text()
#     content = bs.find('div', {'id':'mw-content-text'}).find('p').get_text()
#     store(title, content)
#     return bs.find('div', {'id':'bodyContent'}).findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))

# links = getLinks('/wiki/Kevin_Bacon')
# try:
#     while len(links) > 0:
#          newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#          print(newArticle)
#          links = getLinks(newArticle)
# finally:
#     cur.close()
#     conn.close()

# %% [markdown]
# ## Better Database structure

# %%
# taken from GEEKS for GEEKS
# Connecting to sqlite
# connection object
db = sqlite3.connect('wikipedia.sqlite')
 
# cursor object
cursor = db.cursor()
 
# Drop the table if already exists.
cursor.execute("DROP TABLE IF EXISTS pages")
 
# Creating table
# note primary key automatically auto increments
table = """ CREATE TABLE pages (
            id INTEGER PRIMARY KEY,
            url VARCHAR(255),
            created TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        ); """
 
cursor.execute(table)

table = """ CREATE TABLE links (
            id INTEGER PRIMARY KEY,
            fromPageId INTEGER NULL,
            toPageId INTEGER NULL,
            created TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        ); """
 
cursor.execute(table)
 
print("Table is Ready")
 
# Close the connection
db.close()
# Out:
# Table is Ready

# %%
def insertPageIfNotExists(url, cursor):
    cursor.execute(f'SELECT id FROM pages WHERE url = "{url}" LIMIT 1')
    page = cursor.fetchone()
    if not page:
        cursor.execute(f'INSERT INTO pages (url) VALUES ("{url}")')
        cursor.connection.commit()
        return cursor.lastrowid
    else:
        return page[0]

def loadPages(cursor):
    cursor.execute('SELECT url FROM pages')
    return [row[0] for row in cursor.fetchall()]

def insertLink(fromPageId, toPageId, cursor):
    cursor.execute(f'SELECT EXISTS(SELECT 1 FROM links WHERE fromPageId = {int(fromPageId)} AND toPageId = {int(toPageId)})')
    if not cursor.fetchone()[0]:
        cursor.execute(f'INSERT INTO links (fromPageId, toPageId) VALUES ({int(fromPageId)}, {int(toPageId)})')
        cursor.connection.commit()

def pageHasLinks(pageId, cursor):
    cursor.execute(f'SELECT EXISTS(SELECT 1 FROM links WHERE fromPageId = {int(pageId)})')
    return cursor.fetchone()[0]


def getLinks(pageUrl, recursionLevel, pages, cursor):
    if recursionLevel > 4:
        return

    pageId = insertPageIfNotExists(pageUrl, cursor)
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    links = bs.findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))
    links = [link.attrs['href'] for link in links]

    for link in links:
        linkId = insertPageIfNotExists(link, cursor)
        insertLink(pageId, linkId, cursor)
        if not pageHasLinks(linkId, cursor):
            print(f'Getting {link}')
            pages.append(link)
            getLinks(link, recursionLevel+1, pages, cursor)
        else:
            print(f'Already fetched {link}')

# %%
# with sqlite3.connect('wikipedia.sqlite') as db:
#     print(db.execute('SELECT * FROM pages WHERE url = "/wiki/Kevin_Bacon"').fetchone())

# %%
db = sqlite3.connect('wikipedia.sqlite')
cursor = db.cursor()

getLinks('/wiki/Kevin_Bacon', 0, loadPages(cursor), cursor) 
db.close()
# Out:
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Kevin_Bacon
# Already fetched /wiki/Kevin_Bacon
# Already fetched /wiki/Kevin_Bacon
# Getting /wiki/Kevin_Bacon_(disambiguation)
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Kevin_Bacon_(disambiguation)
# Already fetched /wiki/Kevin_Bacon_(disambiguation)
# Already fetched /wiki/Kevin_Bacon_(disambiguation)
# Already fetched /wiki/Kevin_Bacon
# Getting /wiki/Kevin_Bacon_(producer)
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Kevin_Bacon_(producer)
# Already fetched /wiki/Kevin_Bacon_(producer)
# Already fetched /wiki/Kevin_Bacon_(producer)
# Already fetched /wiki/Kevin_Bacon_(disambiguation)
# Getting /wiki/Rotherham
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Rotherham
# Already fetched /wiki/Rotherham
# Already fetched /wiki/Rotherham
# Getting /wiki/Geographic_coordinate_system
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Geographic_coordinate_system
# Already fetched /wiki/Geographic_coordinate_system
# Already fetched /wiki/Geographic_coordinate_system
# Getting /wiki/Spatial_reference_system
# Getting /wiki/Geodesy
# Getting /wiki/Geodesy
# Getting /wiki/Geodynamics
# Getting /wiki/Geomatics
# Getting /wiki/History_of_geodesy
# Getting /wiki/Geographical_distance
# Getting /wiki/Geoid
# Getting /wiki/Figure_of_the_Earth
# Getting /wiki/Earth_radius
# Getting /wiki/Earth%27s_circumference
# Getting /wiki/Geodetic_coordinates
# Getting /wiki/Geodetic_datum
# Getting /wiki/Geodesic
# Getting /wiki/Horizontal_position_representation
# Getting /wiki/Latitude
# Getting /wiki/Longitude
# Getting /wiki/Map_projection
# Getting /wiki/Reference_ellipsoid
# Getting /wiki/Satellite_geodesy
# Getting /wiki/Spatial_reference_system
# Getting /wiki/Spatial_relation
# Getting /wiki/Vertical_position
# Getting /wiki/Satellite_navigation
# Getting /wiki/Global_Positioning_System
# Getting /wiki/GLONASS
# Getting /wiki/BeiDou
# Getting /wiki/Galileo_(satellite_navigation)
# Getting /wiki/Indian_Regional_Navigation_Satellite_System
# Getting /wiki/Quasi-Zenith_Satellite_System
# Getting /wiki/Discrete_Global_Grid
# Getting /wiki/Sea_Level_Datum_of_1929
# Getting /wiki/OSGB36
# Getting /wiki/SK-42_reference_system
# Getting /wiki/ED50
# Getting /wiki/South_American_Datum#SAD69
# Getting /wiki/GRS_80
# Getting /wiki/ISO_6709
# Getting /wiki/North_American_Datum#North_American_Datum_of_1983
# Getting /wiki/World_Geodetic_System
# Getting /wiki/North_American_Vertical_Datum_of_1988
# Getting /wiki/European_Terrestrial_Reference_System_1989
# Getting /wiki/Restrictions_on_geographic_data_in_China
# Getting /wiki/Geo_URI_scheme
# Getting /wiki/International_Terrestrial_Reference_System
# Getting /wiki/SRID
# Getting /wiki/Universal_Transverse_Mercator_coordinate_system
# Getting /wiki/Spherical_coordinate_system
# Getting /wiki/Geodetic_coordinates
# Getting /wiki/Position_(geometry)
# Getting /wiki/Earth
# Getting /wiki/Latitude
# Getting /wiki/Longitude
# Getting /wiki/Spatial_reference_system
# Getting /wiki/Tuple
# Getting /wiki/Cartesian_coordinate_system
# Getting /wiki/Scandinavia
# Getting /wiki/Quaternary_glaciation
# Getting /wiki/Scotland
# Getting /wiki/World_Geodetic_System
# Getting /wiki/Global_Positioning_System
# Getting /wiki/International_Terrestrial_Reference_System_and_Frame
# Getting /wiki/Continental_drift
# Getting /wiki/Crustal_deformation
# Getting /wiki/North_American_Datum
# Getting /wiki/ED50
# Getting /wiki/OSGB36
# Getting /wiki/ED50
# Getting /wiki/NATO
# Getting /wiki/Geographic_coordinate_conversion#Datum_transformations
# Getting /wiki/Helmert_transformation
# Getting /wiki/Translation_(geometry)
# Getting /wiki/North_American_Datum#North_American_Datum_of_1983
# Getting /wiki/Length_of_a_degree_of_latitude
# Getting /wiki/Length_of_a_degree_of_longitude
# Getting /wiki/Arc_length#Great_circles_on_Earth
# Getting /wiki/World_Geodetic_System#WGS84
# Getting /wiki/Sea_level
# Getting /wiki/Metre
# Getting /wiki/Equator
# Getting /wiki/Earth_radius#Meridional_Earth_radius
# Getting /wiki/Spheroid#Oblate_spheroids
# Getting /wiki/Latitude#Parametric_(or_reduced)_latitude
# Getting /wiki/Saint_Petersburg
# Getting /wiki/Greenwich
# Getting /wiki/Bordeaux
# Getting /wiki/New_Orleans
# Getting /wiki/Quito
# Getting /wiki/Maidenhead_Locator_System
# Getting /wiki/World_Geographic_Reference_System
# Getting /wiki/Global_Area_Reference_System
# Getting /wiki/Open_Location_Code
# Getting /wiki/Geohash
# Getting /wiki/Z-order_curve
# Getting /wiki/Mapcode
# Getting /wiki/What3words
# Getting /wiki/Decimal_degrees
# Getting /wiki/Geographical_distance
# Getting /wiki/Geographic_information_system
# Getting /wiki/Geo_URI_scheme
# Getting /wiki/ISO_6709
# Getting /wiki/Linear_referencing
# Getting /wiki/Primary_direction
# Getting /wiki/Planetary_coordinate_system
# Getting /wiki/Selenographic_coordinate_system
# Getting /wiki/Spatial_reference_system
# Getting /wiki/International_Cartographic_Association
# Getting /wiki/Circumference_of_the_Earth
# Getting /wiki/Ellipsoid
# Getting /wiki/ISBN_(identifier)
# Getting /wiki/Dunedin
# Getting /wiki/ISBN_(identifier)
# Getting /wiki/ISBN_(identifier)
# Getting /wiki/ISBN_(identifier)
# Getting /wiki/Wayback_Machine
# Getting /wiki/KStars
# Getting /wiki/Linux
# Getting /wiki/KDE
# Getting /wiki/Wayback_Machine
# Getting /wiki/Circle_of_latitude
# Getting /wiki/Meridian_(geography)
# Getting /wiki/Equator
# Getting /wiki/Tropic_of_Cancer
# Getting /wiki/Tropic_of_Capricorn
# Getting /wiki/Arctic_Circle
# Getting /wiki/Antarctic_Circle
# Getting /wiki/Equator
# Getting /wiki/Tropic_of_Cancer
# Getting /wiki/Tropic_of_Capricorn
# Getting /wiki/Arctic_Circle
# Getting /wiki/Antarctic_Circle
# Getting /wiki/Equator
# Getting /wiki/Tropic_of_Cancer
# Getting /wiki/Tropic_of_Capricorn
# Getting /wiki/Arctic_Circle
# Getting /wiki/Antarctic_Circle
# Getting /wiki/Western_Hemisphere
# Getting /wiki/IERS_Reference_Meridian
# Getting /wiki/40th_parallel_south
# Getting /wiki/50th_parallel_south
# Getting /wiki/60th_parallel_south
# Getting /wiki/70th_parallel_south
# Getting /wiki/80th_parallel_south
# Getting /wiki/South_Pole
# Getting /wiki/5th_parallel_north
# Getting /wiki/Northern_Hemisphere
# Getting /wiki/15th_parallel_north
# Getting /wiki/25th_parallel_north
# Getting /wiki/35th_parallel_north
# Getting /wiki/45th_parallel_north
# Getting /wiki/55th_parallel_north
# Getting /wiki/65th_parallel_north
# Getting /wiki/75th_parallel_north
# Getting /wiki/Arctic_Ocean
# Getting /wiki/5th_parallel_south
# Getting /wiki/Southern_Hemisphere
# Getting /wiki/15th_parallel_south
# Getting /wiki/25th_parallel_south
# Getting /wiki/35th_parallel_south
# Getting /wiki/45th_parallel_south
# Getting /wiki/55th_parallel_south
# Getting /wiki/65th_parallel_south
# Getting /wiki/75th_parallel_south
# Getting /wiki/Antarctica
# Getting /wiki/45%C3%9790_points
# Getting /wiki/45%C3%9790_points
# Getting /wiki/45%C3%9790_points
# Getting /wiki/45%C3%9790_points
# Getting /wiki/Rotherham_(disambiguation)
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Rotherham_(disambiguation)
# Already fetched /wiki/Rotherham_(disambiguation)
# Already fetched /wiki/Rotherham_(disambiguation)
# Already fetched /wiki/Rotherham
# Getting /wiki/Rotherham_(UK_Parliament_constituency)
# Getting /wiki/Metropolitan_Borough_of_Rotherham
# Getting /wiki/Rotherham,_New_Zealand
# Getting /wiki/Alan_Rotherham
# Getting /wiki/Arthur_Rotherham
# Getting /wiki/Gerard_Rotherham
# Getting /wiki/Hugh_Rotherham
# Getting /wiki/Joseph_Bryant_Rotherham
# Getting /wiki/Roland_Rotherham
# Getting /wiki/Thomas_Rotherham
# Getting /wiki/Edward_Rotheram
# Getting /wiki/Steve_Rotheram
# Getting /wiki/HMS_Rotherham_(H09)
# Getting /wiki/Baron_Rotherham
# Getting /wiki/Rotherham_United_F.C.
# Getting /wiki/Rotherham_child_sexual_exploitation_scandal
# Getting /wiki/Town
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Town
# Already fetched /wiki/Town
# Already fetched /wiki/Town
# Getting /wiki/Town_(disambiguation)
# Getting /wiki/Towns_(disambiguation)
# Getting /wiki/Small_Town_(disambiguation)
# Getting /wiki/Reading,_Berkshire
# Getting /wiki/Porvoo
# Getting /wiki/Lemgo
# Getting /wiki/Davos
# Getting /wiki/Skalica
# Getting /wiki/Mecca
# Getting /wiki/F%C3%A1tima,_Portugal
# Getting /wiki/Viljandi
# Getting /wiki/Human_settlement
# Getting /wiki/Village
# Getting /wiki/City
# Getting /wiki/German_language
# Getting /wiki/Dutch_language
# Getting /wiki/Old_Norse
# Getting /wiki/Proto-Germanic_language
# Getting /wiki/Proto-Celtic_language
# Getting /wiki/Old_Irish
# Getting /wiki/Welsh_language
# Getting /wiki/Palisade
# Getting /wiki/Het_Loo_Palace
# Getting /wiki/Apeldoorn
# Getting /wiki/William_III_of_England
# Getting /wiki/Regierungsbezirk
# Getting /wiki/Comarca
# Getting /wiki/Comune
# Getting /wiki/Frazione
# Getting /wiki/Freguesia
# Getting /wiki/Fu_(administrative_division)
# Getting /wiki/Gemeinde_(Austria)
# Getting /wiki/Gemeinde_(Germany)
# Getting /wiki/Gemeinde_(South_Tyrol)
# Getting /wiki/Gemeinde_(Switzerland)
# Getting /wiki/Gemeente_(disambiguation)
# Getting /wiki/Gmina
# Getting /wiki/Hromada
# Getting /wiki/Jude%C8%9B
# Getting /wiki/Kampong
# Getting /wiki/Municipalities_of_Finland
# Getting /wiki/Municipalities_of_Sweden
# Getting /wiki/L%C3%A4n
# Getting /wiki/Regions_of_Finland
# Getting /wiki/Localit%C3%A0
# Getting /wiki/Regions_of_Finland
# Getting /wiki/Counties_of_Hungary
# Getting /wiki/Muban
# Getting /wiki/Mukim
# Getting /wiki/Nj%C3%ABsi_administrative
# Getting /wiki/Oblast
# Getting /wiki/Autonomous_oblast
# Getting /wiki/Okrug
# Getting /wiki/Provinces_of_Iran
# Getting /wiki/Poblacion
# Getting /wiki/Purok
# Getting /wiki/Qark
# Getting /wiki/Raion
# Getting /wiki/Savivaldyb%C4%97
# Getting /wiki/Seni%C5%ABnija
# Getting /wiki/Counties_of_Iran
# Getting /wiki/Sum_(administrative_division)
# Getting /wiki/Sums_of_Inner_Mongolia
# Getting /wiki/S%C3%BDsla
# Getting /wiki/Tehsil
# Getting /wiki/Vingtaine
# Getting /wiki/Commote
# Getting /wiki/Gau_(territory)
# Getting /wiki/Heerlijkheid
# Getting /wiki/Komun%C3%AB
# Getting /wiki/K%C3%B6ping
# Getting /wiki/Korale
# Getting /wiki/Provinces_of_Finland
# Getting /wiki/Provinces_of_Sweden
# Getting /wiki/Maalaiskunta
# Getting /wiki/Maalaiskunta
# Getting /wiki/Nome_(Egypt)
# Getting /wiki/Prefectures_of_Greece
# Getting /wiki/Pagus
# Getting /wiki/Pargana
# Getting /wiki/Plas%C4%83
# Getting /wiki/Rreth
# Getting /wiki/Satrap
# Getting /wiki/Socken
# Getting /wiki/Subah
# Getting /wiki/Syssel
# Getting /wiki/Zhou_(administrative_division)
# Getting /wiki/Census_division
# Getting /wiki/Electoral_district
# Getting /wiki/List_of_administrative_divisions_by_country
# Getting /wiki/Rotherham_Minster
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Main_Page
# Already fetched /wiki/Rotherham_Minster
# Already fetched /wiki/Rotherham_Minster
# Already fetched /wiki/Rotherham_Minster
# Already fetched /wiki/Geographic_coordinate_system
# Getting /wiki/Ordnance_Survey_National_Grid
# Already fetched /wiki/Rotherham
# Getting /wiki/South_Yorkshire
# Getting /wiki/England
# Getting /wiki/Christian_denomination
# Getting /wiki/Church_of_England
# Getting /wiki/Churchmanship
# Getting /wiki/Broad_Church
# Getting /wiki/Dedication_of_churches
# Getting /wiki/All_Saints%27_Day
# Getting /wiki/Sacred_architecture
# Getting /wiki/Decorated_Gothic
# Getting /wiki/Perpendicular_Gothic
# Getting /wiki/Ecclesiastical_province
# Getting /wiki/Leeds_West_(UK_Parliament_constituency)
# Getting /wiki/Normanton,_Pontefract_and_Castleford_(UK_Parliament_constituency)
# Getting /wiki/Rotherham_(UK_Parliament_constituency)
# Getting /wiki/Selby_and_Ainsty_(UK_Parliament_constituency)
# Getting /wiki/Sheffield_Brightside_and_Hillsborough_(UK_Parliament_constituency)
# Getting /wiki/Sheffield_Central_(UK_Parliament_constituency)
# Getting /wiki/Sheffield_Hallam_(UK_Parliament_constituency)
# Getting /wiki/Sheffield_Heeley_(UK_Parliament_constituency)
# Getting /wiki/Sheffield_South_East_(UK_Parliament_constituency)
# Getting /wiki/Wakefield_(UK_Parliament_constituency)
# Getting /wiki/Wentworth_and_Dearne_(UK_Parliament_constituency)
# Getting /wiki/York_Central_(UK_Parliament_constituency)
# Getting /wiki/Conservative_Party_(UK)
# Getting /wiki/Beverley_and_Holderness_(UK_Parliament_constituency)
# Getting /wiki/Brigg_and_Goole_(UK_Parliament_constituency)
# Getting /wiki/Calder_Valley_(UK_Parliament_constituency)
# Getting /wiki/Cleethorpes_(UK_Parliament_constituency)
# Getting /wiki/Colne_Valley_(UK_Parliament_constituency)
# Getting /wiki/Dewsbury_(UK_Parliament_constituency)
# Getting /wiki/Don_Valley_(UK_Parliament_constituency)
# Getting /wiki/East_Yorkshire_(UK_Parliament_constituency)
# Getting /wiki/Elmet_and_Rothwell_(UK_Parliament_constituency)
# Getting /wiki/Great_Grimsby_(UK_Parliament_constituency)
# Getting /wiki/Haltemprice_and_Howden_(UK_Parliament_constituency)
# Getting /wiki/Harrogate_and_Knaresborough_(UK_Parliament_constituency)
# Getting /wiki/Keighley_(UK_Parliament_constituency)
# Getting /wiki/Morley_and_Outwood_(UK_Parliament_constituency)
# Getting /wiki/Penistone_and_Stocksbridge_(UK_Parliament_constituency)
# Getting /wiki/Pudsey_(UK_Parliament_constituency)
# Getting /wiki/Richmond_(Yorks)_(UK_Parliament_constituency)
# Getting /wiki/Rother_Valley_(UK_Parliament_constituency)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[182], line 4
#       1 db = sqlite3.connect('wikipedia.sqlite')
#       2 cursor = db.cursor()
# ----> 4 getLinks('/wiki/Kevin_Bacon', 0, loadPages(cursor), cursor)
#       5 db.close()
#
# Cell In[180], line 42, in getLinks(pageUrl, recursionLevel, pages, cursor)
#      40     print(f'Getting {link}')
#      41     pages.append(link)
# ---> 42     getLinks(link, recursionLevel+1, pages, cursor)
#      43 else:
#      44     print(f'Already fetched {link}')
#
# Cell In[180], line 42, in getLinks(pageUrl, recursionLevel, pages, cursor)
#      40     print(f'Getting {link}')
#      41     pages.append(link)
# ---> 42     getLinks(link, recursionLevel+1, pages, cursor)
#      43 else:
#      44     print(f'Already fetched {link}')
#
#     [... skipping similar frames: getLinks at line 42 (1 times)]
#
# Cell In[180], line 42, in getLinks(pageUrl, recursionLevel, pages, cursor)
#      40     print(f'Getting {link}')
#      41     pages.append(link)
# ---> 42     getLinks(link, recursionLevel+1, pages, cursor)
#      43 else:
#      44     print(f'Already fetched {link}')
#
# Cell In[180], line 37, in getLinks(pageUrl, recursionLevel, pages, cursor)
#      34 links = [link.attrs['href'] for link in links]
#      36 for link in links:
# ---> 37     linkId = insertPageIfNotExists(link, cursor)
#      38     insertLink(pageId, linkId, cursor)
#      39     if not pageHasLinks(linkId, cursor):
#
# Cell In[180], line 2, in insertPageIfNotExists(url, cursor)
#       1 def insertPageIfNotExists(url, cursor):
# ----> 2     cursor.execute(f'SELECT id FROM pages WHERE url = "{url}" LIMIT 1')
#       3     page = cursor.fetchone()
#       4     if not page:
#
# KeyboardInterrupt:

# %%
with sqlite3.connect('wikipedia.sqlite') as db:
    print(db.execute('SELECT * FROM pages').fetchall())
    print(db.execute('SELECT * FROM links').fetchall())
# Out:
# [(1, '/wiki/Kevin_Bacon', '2024-04-17 02:06:29'), (2, '/wiki/Main_Page', '2024-04-17 02:06:30'), (3, '/wiki/Wikipedia', '2024-04-17 02:06:30'), (4, '/wiki/English_Wikipedia', '2024-04-17 02:06:31'), (5, '/wiki/Internet_encyclopedia', '2024-04-17 02:06:32'), (6, '/wiki/Online_encyclopedia', '2024-04-17 02:06:32'), (7, '/wiki/Encyclopedia', '2024-04-17 02:06:32'), (8, '/wiki/Internet', '2024-04-17 02:06:32'), (9, '/wiki/Encarta', '2024-04-17 02:06:32'), (10, '/wiki/Encyclop%C3%A6dia_Britannica', '2024-04-17 02:06:32'), (11, '/wiki/Encyclopedia.com', '2024-04-17 02:06:32'), (12, '/wiki/Project_Gutenberg', '2024-04-17 02:06:32'), (13, '/wiki/ASCII', '2024-04-17 02:06:32'), (14, '/wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition', '2024-04-17 02:06:32'), (15, '/wiki/Digitization', '2024-04-17 02:06:32'), (16, '/wiki/Lord_Chamberlain', '2024-04-17 02:06:32'), (17, '/wiki/Luqman', '2024-04-17 02:06:32'), (18, '/wiki/CD-ROM', '2024-04-17 02:06:32'), (19, '/wiki/Copyright', '2024-04-17 02:06:32'), (20, '/wiki/Website', '2024-04-17 02:06:32'), (21, '/wiki/Easton%27s_Bible_Dictionary_(1897)', '2024-04-17 02:06:32'), (22, '/wiki/Christian_Classics_Ethereal_Library', '2024-04-17 02:06:32'), (23, '/wiki/Bartleby.com', '2024-04-17 02:06:32'), (24, '/wiki/Columbia_Encyclopedia', '2024-04-17 02:06:32'), (25, '/wiki/Wikisource', '2024-04-17 02:06:32'), (26, '/wiki/Usenet', '2024-04-17 02:06:32'), (27, '/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy', '2024-04-17 02:06:32'), (28, '/wiki/Douglas_Adams', '2024-04-17 02:06:32'), (29, '/wiki/H2g2', '2024-04-17 02:06:32'), (30, '/wiki/Interpedia', '2024-04-17 02:06:32'), (31, '/wiki/College_of_William_%26_Mary', '2024-04-17 02:06:32'), (32, '/wiki/Charleston_Conference', '2024-04-17 02:06:32'), (33, '/wiki/Iowa_City,_Iowa', '2024-04-17 02:06:32'), (34, '/wiki/Free_content', '2024-04-17 02:06:32'), (35, '/wiki/Wikipedia_community', '2024-
), (77, 48, 67, '2024-04-17 02:06:33'), (78, 48, 68, '2024-04-17 02:06:33'), (79, 48, 25, '2024-04-17 02:06:33'), (80, 48, 69, '2024-04-17 02:06:33'), (81, 48, 70, '2024-04-17 02:06:33'), (82, 48, 71, '2024-04-17 02:06:33'), (83, 48, 72, '2024-04-17 02:06:33'), (84, 48, 73, '2024-04-17 02:06:33'), (85, 48, 74, '2024-04-17 02:06:33'), (86, 48, 75, '2024-04-17 02:06:33'), (87, 48, 76, '2024-04-17 02:06:33'), (88, 48, 77, '2024-04-17 02:06:33'), (89, 48, 78, '2024-04-17 02:06:33'), (90, 48, 79, '2024-04-17 02:06:33'), (91, 48, 80, '2024-04-17 02:06:33'), (92, 48, 81, '2024-04-17 02:06:33'), (93, 48, 82, '2024-04-17 02:06:33'), (94, 48, 83, '2024-04-17 02:06:33'), (95, 48, 84, '2024-04-17 02:06:33'), (96, 48, 85, '2024-04-17 02:06:33'), (97, 48, 86, '2024-04-17 02:06:33'), (98, 48, 87, '2024-04-17 02:06:33'), (99, 48, 38, '2024-04-17 02:06:33'), (100, 48, 88, '2024-04-17 02:06:33'), (101, 48, 89, '2024-04-17 02:06:33'), (102, 48, 90, '2024-04-17 02:06:33'), (103, 48, 91, '2024-04-17 02:06:33'), (104, 48, 92, '2024-04-17 02:06:33'), (105, 48, 93, '2024-04-17 02:06:33'), (106, 48, 94, '2024-04-17 02:06:33'), (107, 48, 95, '2024-04-17 02:06:33'), (108, 48, 96, '2024-04-17 02:06:33'), (109, 48, 97, '2024-04-17 02:06:33'), (110, 48, 98, '2024-04-17 02:06:33'), ...

# %%
# LIKE BEFORE
# from urllib.request import urlopen
# from bs4 import BeautifulSoup
# import re
# import pymysql
# from random import shuffle

# conn = pymysql.connect(host='127.0.0.1', unix_socket='/tmp/mysql.sock',
#                        user='root', passwd='password', db='mysql', charset='utf8')
# cur = conn.cursor()
# cur.execute('USE wikipedia')

# def insertPageIfNotExists(url):
#     cur.execute('SELECT id FROM pages WHERE url = %s LIMIT 1', (url))
#     page = cur.fetchone()
#     if not page:
#         cur.execute('INSERT INTO pages (url) VALUES (%s)', (url))
#         conn.commit()
#         return cur.lastrowid
#     else:
#         return page[0]

# def loadPages():
#     cur.execute('SELECT url FROM pages')
#     return [row[0] for row in cur.fetchall()]

# def insertLink(fromPageId, toPageId):
#     cur.execute('SELECT EXISTS(SELECT 1 FROM links WHERE fromPageId = %s AND toPageId = %s)',(int(fromPageId), int(toPageId)))
#     if not cur.fetchone()[0]:
#         cur.execute('INSERT INTO links (fromPageId, toPageId) VALUES (%s, %s)', 
#                     (int(fromPageId), int(toPageId)))
#         conn.commit()

# def pageHasLinks(pageId):
#     cur.execute('SELECT EXISTS(SELECT 1 FROM links WHERE fromPageId = %s)', (int(pageId)))
#     return cur.fetchone()[0]


# def getLinks(pageUrl, recursionLevel, pages):
#     if recursionLevel > 4:
#         return

#     pageId = insertPageIfNotExists(pageUrl)
#     html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#     bs = BeautifulSoup(html, 'html.parser')
#     links = bs.findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#     links = [link.attrs['href'] for link in links]

#     for link in links:
#         linkId = insertPageIfNotExists(link)
#         insertLink(pageId, linkId)
#         if not pageHasLinks(linkId):
#             print(f'Getting {link}')
#             pages.append(link)
#             getLinks(link, recursionLevel+1, pages)
#         else:
#             print(f'Already fetched {link}')
        
        
# getLinks('/wiki/Kevin_Bacon', 0, loadPages()) 
# cur.close()
# conn.close()

# %% [markdown]
# NOTE: I don't have an email server, and I've played around before iwth outlook. So I won't play around with the stuff below.

# %%
import smtplib
from email.mime.text import MIMEText

msg = MIMEText('The body of the email is here')

msg['Subject'] = 'An Email Alert'
msg['From'] = 'ryan@pythonscraping.com'
msg['To'] = 'webmaster@pythonscraping.com'

s = smtplib.SMTP('localhost')
s.send_message(msg)
s.quit()

# %%
import smtplib
from email.mime.text import MIMEText
from bs4 import BeautifulSoup
from urllib.request import urlopen
import time

def sendMail(subject, body):
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] ='christmas_alerts@pythonscraping.com'
    msg['To'] = 'ryan@pythonscraping.com'

    s = smtplib.SMTP('localhost')
    s.send_message(msg)
    s.quit()

bs = BeautifulSoup(urlopen('https://isitchristmas.com/'), 'html.parser')
while(bs.find('a', {'id':'answer'}).attrs['title'] == 'NO'):
    print('It is not Christmas yet.')
    time.sleep(3600)
    bs = BeautifulSoup(urlopen('https://isitchristmas.com/'), 'html.parser')
sendMail('It\'s Christmas!', 
         'According to https://isitchristmas.com/, it is Christmas!')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-1-576712b12bce> in <module>()
#      21     bs = BeautifulSoup(urlopen('https://isitchristmas.com/'), 'html.parser')
#      22 sendMail('It\'s Christmas!',
# ---> 23          'According to http://itischristmas.com, it is Christmas!')
#
# <ipython-input-1-576712b12bce> in sendMail(subject, body)
#      11     msg['To'] = 'ryan@pythonscraping.com'
#      12
# ---> 13     s = smtplib.SMTP('localhost')
#      14     s.send_message(msg)
#      15     s.quit()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     249
#     250         if host:
# --> 251             (code, msg) = self.connect(host, port)
#     252             if code != 220:
#     253                 raise SMTPConnectError(code, msg)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/smtplib.py in connect(self, host, port, source_address)
#     333         if self.debuglevel > 0:
#     334             self._print_debug('connect:', (host, port))
# --> 335         self.sock = self._get_socket(host, port, self.timeout)
#     336         self.file = None
#     337         (code, msg) = self.getreply()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/smtplib.py in _get_socket(self, host, port, timeout)
#     304             self._print_debug('connect: to', (host, port), self.source_address)
#     305         return socket.create_connection((host, port), timeout,
# --> 306                                         self.source_address)
#     307
#     308     def connect(self, host='localhost', port=0, source_address=None):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     720
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#     724         raise error("getaddrinfo returns an empty list")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#     715
#
# ConnectionRefusedError: [Errno 61] Connection refused

# %%
'
